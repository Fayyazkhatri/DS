# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflix_titles.csv")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data["country"].replace(np.nan, "None",inplace=True)

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data["country"].replace({"None": "USA"}, inplace=True)

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.groupby(["type", "country"]).count()
# Out:
#                                                             show_id  title  \
# type    country
# Movie   , France, Algeria                                         1      1
#         Argentina                                                38     38
#         Argentina, Brazil, France, Poland, Germany, Den...        1      1
#         Argentina, Chile                                          2      2
#         Argentina, Chile, Peru                                    1      1
# ...                                                             ...    ...
# TV Show United States, South Korea, China                         2      2
#         United States, Sweden                                     1      1
#         United States, United Kingdom                             9      9
#         United States, United Kingdom, Australia                  1      1
#         Uruguay, Germany                                          1      1
#
# ...

# %%
data.loc[data.release_year >= 2017].count()
# Out:
# show_id         4754
# type            4754
# title           4754
# director        3007
# cast            4176
# country         4754
# date_added      4753
# release_year    4754
# rating          4753
# duration        4753
# listed_in       4754
# description     4754
# dtype: int64

# %%
data.loc[data.release_year >= 2018].count()
# Out:
# show_id         3722
# type            3722
# title           3722
# director        2234
# cast            3264
# country         3722
# date_added      3721
# release_year    3722
# rating          3722
# duration        3722
# listed_in       3722
# description     3722
# dtype: int64

# %%
data.loc[data["release_year"]== 2017 ]
# Out:
#      show_id     type                            title  \
# 38       s39    Movie              Birth of the Dragon
# 89       s90  TV Show                      Mighty Raju
# 105     s106    Movie                 Angamaly Diaries
# 118     s119    Movie                          Gurgaon
# 128     s129    Movie  Agatha Christie's Crooked House
# ...      ...      ...                              ...
# 8753   s8754    Movie                        Withdrawn
# 8758   s8759  TV Show           World's Busiest Cities
# 8765   s8766    Movie                               XX
# 8786   s8787    Movie                     You Can Tutu
# 8787   s8788    Movie        You Can’t Fight Christmas
#
#                                                director  \
# 38                                         George Nolfi
# 89                                                  NaN
# 105                                Lijo Jose Pellissery
# 118                                       Shanker Raman
# ...

# %%
data.loc[data["release_year"]== 2018]
# Out:
#      show_id     type                                              title  \
# 21       s22  TV Show                             Resurrection: Ertugrul
# 37       s38  TV Show                                        Angry Birds
# 73       s74    Movie                                       King of Boys
# 94       s95    Movie                                          Show Dogs
# 96       s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# ...      ...      ...                                                ...
# 8732   s8733    Movie                                      White Chamber
# 8743   s8744    Movie                                           Wildlife
# 8774   s8775    Movie                                          يوم الدين
# 8775   s8776  TV Show                                    Yeh Meri Family
# 8803   s8804  TV Show                                        Zombie Dumb
#
#              director                                               cast  \
# ...

# %%
data.groupby(["type","release_year"]).count()
# Out:
#                       show_id  title  director  cast  country  date_added  \
# type    release_year
# Movie   1942                2      2         2     1        2           2
#         1943                3      3         3     0        3           3
#         1944                3      3         3     1        3           3
#         1945                3      3         3     1        3           3
#         1946                1      1         1     1        1           1
# ...                       ...    ...       ...   ...      ...         ...
# TV Show 2017              265    265        25   236      265         265
#         2018              380    380        23   328      380         379
#         2019              397    397        31   350      397         397
#         2020              436    436        53   357      436         436
#         2021              315    315        45   250      315         315
#
# ...

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.groupby("type")["country"].value_counts()
# Out:
# type     country
# Movie    United States                               2058
#          India                                        893
#          USA                                          440
#          United Kingdom                               206
#          Canada                                       122
#                                                      ...
# TV Show  United States, Russia                          1
#          United States, Singapore                       1
#          United States, Sweden                          1
#          United States, United Kingdom, Australia       1
#          Uruguay, Germany                               1
# Name: country, Length: 849, dtype: int64

# %%
data.groupby("type")["release_year"].value_counts()
# Out:
# type     release_year
# Movie    2017            767
#          2018            767
#          2016            658
#          2019            633
#          2020            517
#                         ...
# TV Show  1979              1
#          1981              1
#          1985              1
#          1989              1
#          1991              1
# Name: release_year, Length: 119, dtype: int64
