# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("netflixData.csv")

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Production Country', data= data)
# Out:
# <AxesSubplot:xlabel='Production Country', ylabel='count'>

# %%
data.sort_values("Production Country")
# Out:
#                                    Show Id                        Title  \
# 4130  6b930e75-e34a-478c-b262-6e234f16442c  Sebastián Marcelo Wainraich
# 4948  10658c04-71dc-4232-9758-e9493b5f039f        The Kirlian Frequency
# 5208  10a71477-d835-47d4-84ca-1765e2ad2ed7                      The Son
# 4138  311eee41-cfc4-4b2a-bf23-4efecf6fef75        Secreto bien guardado
# 1613  52a26675-c21f-4a68-a6d2-93e1702c4ce4     Fernando Sanjiao: Hombre
# ...                                    ...                          ...
# 5943  66bd36e5-8c75-4bcb-8e12-b7eb6cd5c512                    Zero Hour
# 5959  29166831-eb84-4a0d-b2e0-e4c13fea7c6d            Zulu Man in Japan
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                 دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                         海的儿子
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d          최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
data.sort_values(by="Production Country",ascending=False)
# Out:
#                                    Show Id                Title  \
# 1091  8601b603-f0e5-4ada-b82d-a26a9dd35fab             Cook Off
# 2073  caabdea2-1a4e-4b9b-a9a4-0628089563b3    Hitler - A Career
# 872   6811a110-bb88-456b-b0e2-3c2d96a9b39f     Camellia Sisters
# 4296  c1bcfd95-7165-4d10-8c9f-cf1ad1887600  Sky Tour: The Movie
# 1743  a9d9f6e7-9bb2-4000-aa0c-87b36901c094                Furie
# ...                                    ...                  ...
# 5943  66bd36e5-8c75-4bcb-8e12-b7eb6cd5c512            Zero Hour
# 5959  29166831-eb84-4a0d-b2e0-e4c13fea7c6d    Zulu Man in Japan
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6         دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                 海的儿子
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d  최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# 1091  Yearning for a better life, a single mother wi...
# 2073  This documentary examines how Adolf Hitler's t...
# ...

# %%
sns.countplot(x='Content Type', data= data)
# Out:
# <AxesSubplot:xlabel='Content Type', ylabel='count'>

# %%
sorted_data = data.sort_values(by=["Production Country"])
sorted_data
# Out:
#                                    Show Id                        Title  \
# 4130  6b930e75-e34a-478c-b262-6e234f16442c  Sebastián Marcelo Wainraich
# 4948  10658c04-71dc-4232-9758-e9493b5f039f        The Kirlian Frequency
# 5208  10a71477-d835-47d4-84ca-1765e2ad2ed7                      The Son
# 4138  311eee41-cfc4-4b2a-bf23-4efecf6fef75        Secreto bien guardado
# 1613  52a26675-c21f-4a68-a6d2-93e1702c4ce4     Fernando Sanjiao: Hombre
# ...                                    ...                          ...
# 5943  66bd36e5-8c75-4bcb-8e12-b7eb6cd5c512                    Zero Hour
# 5959  29166831-eb84-4a0d-b2e0-e4c13fea7c6d            Zulu Man in Japan
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                 دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                         海的儿子
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d          최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
data["Production Country"].value_counts()
# Out:
# United States                    1792
# India                             628
# United Kingdom                    244
# Japan                             221
# South Korea                       167
#                                  ...
# Spain, Italy                        1
# United States, Switzerland          1
# Canada, Germany, South Africa       1
# Turkey, India                       1
# Ireland, United Kingdom             1
# Name: Production Country, Length: 509, dtype: int64

# %%
plot = data["Production Country"].value_counts().head(10).to_numpy()
label = data["Production Country"].value_counts().head(10).keys()

# %%
plt.figure(figsize = (30,10))
sns.set(font_scale = 1.5)
plt.bar(label,plot)
plt.show()

# %%
data['Production Country'].value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data["Content Type"].value_counts()
# Out:
# Movie      3867
# TV Show    2100
# Name: Content Type, dtype: int64

# %%
sns.countplot(x='Production Country', data= data )
# Out:
# <AxesSubplot:xlabel='Production Country', ylabel='count'>
